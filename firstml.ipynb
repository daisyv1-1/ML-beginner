# %% [markdown]
# <a href="https://colab.research.google.com/github/daisyv1-1/ML-beginner/blob/main/firstml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# this imports required libraries<br>
# tensorflow is a open source library by google

# %%
model=tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
X=np.array([-1, 0, 2, 3, 4, 5, 6, 7], dtype=int)
Y=np.array([-8, 0, 13, 20, 27, 34, 41, 48], dtype=int)
model.fit(X, Y, epochs=300)
print(model.predict([9]))
# Out:
# Epoch 1/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0856
# Epoch 2/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0856
# Epoch 3/300
# 1/1 [==============================] - 0s 9ms/step - loss: 0.0856
# Epoch 4/300
# 1/1 [==============================] - 0s 8ms/step - loss: 0.0856
# Epoch 5/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0856
# Epoch 6/300
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0856
# Epoch 7/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0856
# Epoch 8/300
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0856
# Epoch 9/300
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0856
# Epoch 10/300
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0856
# Epoch 11/300
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0856
# Epoch 12/300
# 1/1 [==============================] - 0s 7ms/step - loss: 0.0856
# ...
